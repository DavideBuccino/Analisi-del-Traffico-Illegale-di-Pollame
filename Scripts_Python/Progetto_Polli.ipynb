# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("FAOSTAT_data_en_3-25-2025.csv")
df
# Out:
#       Domain Code                        Domain  Area Code (M49)         Area  \
# 0             TCL  Crops and livestock products                4  Afghanistan
# 1             TCL  Crops and livestock products                4  Afghanistan
# 2             TCL  Crops and livestock products                4  Afghanistan
# 3             TCL  Crops and livestock products                4  Afghanistan
# 4             TCL  Crops and livestock products                4  Afghanistan
# ...           ...                           ...              ...          ...
# 42950         TCL  Crops and livestock products              716     Zimbabwe
# 42951         TCL  Crops and livestock products              716     Zimbabwe
# 42952         TCL  Crops and livestock products              716     Zimbabwe
# 42953         TCL  Crops and livestock products              716     Zimbabwe
# 42954         TCL  Crops and livestock products              716     Zimbabwe
#
#        Element Code          Element  Item Code (CPC)     Item  Year Code  \
# 0              5608  Import quantity          2112.00  Buffalo       2014
# 1              5622     Import value          2112.00  Buffalo       2014
# 2              5908  Export quantity          2121.01   Camels       2014
# 3              5922     Export value          2121.01   Camels       2014
# 4              5908  Export quantity          2121.01   Camels       2016
# ...             ...              ...              ...      ...        ...
# 42950          5922     Export value          2152.00  Turkeys       2011
# 42951          5909  Export quantity          2152.00  Turkeys       2012
# 42952          5922     Export value          2152.00  Turkeys       2012
# 42953          5909  Export quantity          2152.00  Turkeys       2013
# 42954          5922     Export value          2152.00  Turkeys       2013
#
#        Year      Unit  Value Flag                         Flag Description  \
# 0      2014        An      1    X  Figure from international organizations
# 1      2014  1000 USD      0    X  Figure from international organizations
# 2      2014        An    628    X  Figure from international organizations
# 3      2014  1000 USD    389    X  Figure from international organizations
# 4      2016        An    100    X  Figure from international organizations
# ...     ...       ...    ...  ...                                      ...
# 42950  2011  1000 USD      0    E                          Estimated value
# 42951  2012   1000 An      0    E                          Estimated value
# 42952  2012  1000 USD      0    E                          Estimated value
# 42953  2013   1000 An      0    E                          Estimated value
# 42954  2013  1000 USD      0    E                          Estimated value
#
#                                                  Note
# 0      Estimated data using trading partners database
# 1      Estimated data using trading partners database
# 2      Estimated data using trading partners database
# 3      Estimated data using trading partners database
# 4      Estimated data using trading partners database
# ...                                               ...
# 42950                                             NaN
# 42951                                             NaN
# 42952                                             NaN
# 42953                                             NaN
# 42954                                             NaN
#
# [42955 rows x 15 columns]

# %%
df.head(3)
# Out:
#   Domain Code                        Domain  Area Code (M49)         Area  \
# 0         TCL  Crops and livestock products                4  Afghanistan
# 1         TCL  Crops and livestock products                4  Afghanistan
# 2         TCL  Crops and livestock products                4  Afghanistan
#
#    Element Code          Element  Item Code (CPC)     Item  Year Code  Year  \
# 0          5608  Import quantity          2112.00  Buffalo       2014  2014
# 1          5622     Import value          2112.00  Buffalo       2014  2014
# 2          5908  Export quantity          2121.01   Camels       2014  2014
#
#        Unit  Value Flag                         Flag Description  \
# 0        An      1    X  Figure from international organizations
# 1  1000 USD      0    X  Figure from international organizations
# 2        An    628    X  Figure from international organizations
#
#                                              Note
# 0  Estimated data using trading partners database
# 1  Estimated data using trading partners database
# 2  Estimated data using trading partners database

# %%
df.tail(3)
# Out:
#       Domain Code                        Domain  Area Code (M49)      Area  \
# 42952         TCL  Crops and livestock products              716  Zimbabwe
# 42953         TCL  Crops and livestock products              716  Zimbabwe
# 42954         TCL  Crops and livestock products              716  Zimbabwe
#
#        Element Code          Element  Item Code (CPC)     Item  Year Code  \
# 42952          5922     Export value           2152.0  Turkeys       2012
# 42953          5909  Export quantity           2152.0  Turkeys       2013
# 42954          5922     Export value           2152.0  Turkeys       2013
#
#        Year      Unit  Value Flag Flag Description Note
# 42952  2012  1000 USD      0    E  Estimated value  NaN
# 42953  2013   1000 An      0    E  Estimated value  NaN
# 42954  2013  1000 USD      0    E  Estimated value  NaN

# %%
df.sample(7)
# Out:
#       Domain Code                        Domain  Area Code (M49)         Area  \
# 10863         TCL  Crops and livestock products              203      Czechia
# 37217         TCL  Crops and livestock products              756  Switzerland
# 12017         TCL  Crops and livestock products              218      Ecuador
# 6910          TCL  Crops and livestock products              124       Canada
# 15765         TCL  Crops and livestock products              300       Greece
# 29624         TCL  Crops and livestock products              591       Panama
# 33835         TCL  Crops and livestock products              686      Senegal
#
#        Element Code          Element  Item Code (CPC)               Item  \
# 10863          5922     Export value           2152.0            Turkeys
# 37217          5908  Export quantity           2112.0            Buffalo
# 12017          5909  Export quantity           2191.0  Rabbits and hares
# 6910           5922     Export value           2140.0       Swine / pigs
# 15765          5922     Export value           2131.0             Horses
# 29624          5608  Import quantity           2122.0              Sheep
# 33835          5908  Export quantity           2122.0              Sheep
#
#        Year Code  Year      Unit   Value Flag  \
# 10863       2015  2015  1000 USD   21929    A
# 37217       2014  2014        An       1    A
# 12017       2013  2013   1000 An       0    E
# 6910        2016  2016  1000 USD  329820    A
# 15765       2014  2014  1000 USD     267    A
# 29624       2012  2012        An       0    X
# 33835       2010  2010        An       0    E
#
#                               Flag Description  \
# 10863                          Official figure
# 37217                          Official figure
# 12017                          Estimated value
# 6910                           Official figure
# 15765                          Official figure
# 29624  Figure from international organizations
# 33835                          Estimated value
#
#                                                  Note
# 10863                                             NaN
# 37217                                             NaN
# 12017                                             NaN
# 6910                                              NaN
# 15765                                             NaN
# 29624  Estimated data using trading partners database
# 33835                                             NaN

# %%
df.describe()
# Out:
#        Area Code (M49)  Element Code  Item Code (CPC)     Year Code  \
# count     42955.000000  42955.000000     42955.000000  42955.000000
# mean        433.511070   5744.056804      2143.056875   2013.195530
# std         253.971107    148.630929        26.956087      2.243545
# min           4.000000   5608.000000      2111.000000   2010.000000
# 25%         208.000000   5609.000000      2123.000000   2011.000000
# 50%         422.000000   5622.000000      2133.000000   2013.000000
# 75%         662.000000   5909.000000      2152.000000   2015.000000
# max         894.000000   5922.000000      2199.200000   2017.000000
#
#                Year         Value
# count  42955.000000  4.295500e+04
# mean    2013.195530  3.628702e+04
# std        2.243545  3.514313e+05
# min     2010.000000  0.000000e+00
# 25%     2011.000000  0.000000e+00
# 50%     2013.000000  5.700000e+01
# 75%     2015.000000  1.814500e+03
# max     2017.000000  1.554260e+07

# %%
df["Item"].unique()
# Out:
# array(['Buffalo', 'Camels', 'Cattle', 'Chickens', 'Goats', 'Horses',
#        'Other live animals non food, n.e.c.',
#        'Other live animals, n.e.c.', 'Sheep', 'Swine / pigs', 'Turkeys',
#        'Asses', 'Ducks', 'Geese', 'Mules and hinnies', 'Other camelids',
#        'Rabbits and hares', 'Other rodents'], dtype=object)

# %%
counts_animal = df["Item"].value_counts()

# %%
counts_animal
# Out:
# Item
# Chickens                               4882
# Cattle                                 4729
# Horses                                 4646
# Sheep                                  3887
# Swine / pigs                           3630
# Goats                                  3540
# Other live animals, n.e.c.             2665
# Turkeys                                2509
# Ducks                                  2498
# Other live animals non food, n.e.c.    2290
# Rabbits and hares                      1780
# Asses                                  1776
# Mules and hinnies                      1645
# Buffalo                                 914
# Camels                                  902
# Geese                                   422
# Other camelids                          166
# Other rodents                            74
# Name: count, dtype: int64

# %%
counts_animal.plot.bar()
# Out:
# <Axes: xlabel='Item'>

# %%
pivot = df.pivot_table(index=["Area", "Year"], columns=["Element"], values="Value")
pivot
# Out:
# Element           Export quantity  Export value  Import quantity  Import value
# Area        Year
# Afghanistan 2010         0.000000      0.000000      1474.666667   1191.000000
#             2011         0.000000      0.000000      1594.000000   2142.000000
#             2012         0.000000      0.000000      2817.666667   1474.000000
#             2013         0.000000      0.000000     30923.333333   7942.333333
#             2014       565.000000    182.250000     20200.200000   5769.000000
# ...                           ...           ...              ...           ...
# Zimbabwe    2013        94.909091    166.769231       710.600000    550.454545
#             2014       513.000000    742.500000      1495.666667    967.571429
#             2015       752.666667    973.000000       921.500000   1180.428571
#             2016       227.000000    614.000000       452.857143    639.375000
#             2017       142.666667    557.750000       387.000000    444.500000
#
# [1541 rows x 4 columns]

# %%
pivot.to_excel("pivot.xlsx")

# %%
chicken_filter = df["Item"] == "Chickens"
chicken_filter.value_counts()
# Out:
# Item
# False    38073
# True      4882
# Name: count, dtype: int64

# %%
chickens = df[chicken_filter]
chickens["Item"].unique()
# Out:
# array(['Chickens'], dtype=object)

# %%
chickens["Unit"].value_counts()
# Out:
# Unit
# 1000 An     2441
# 1000 USD    2441
# Name: count, dtype: int64

# %%
chickens["Value Extended"] = chickens["Value"] * 1000
# Out:
# C:\Users\bocci\AppData\Local\Temp\ipykernel_17596\1464814218.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chickens["Value Extended"] = chickens["Value"] * 1000

# %%
chickens
# Out:
#       Domain Code                        Domain  Area Code (M49)         Area  \
# 26            TCL  Crops and livestock products                4  Afghanistan
# 27            TCL  Crops and livestock products                4  Afghanistan
# 28            TCL  Crops and livestock products                4  Afghanistan
# 29            TCL  Crops and livestock products                4  Afghanistan
# 30            TCL  Crops and livestock products                4  Afghanistan
# ...           ...                           ...              ...          ...
# 42775         TCL  Crops and livestock products              716     Zimbabwe
# 42776         TCL  Crops and livestock products              716     Zimbabwe
# 42777         TCL  Crops and livestock products              716     Zimbabwe
# 42778         TCL  Crops and livestock products              716     Zimbabwe
# 42779         TCL  Crops and livestock products              716     Zimbabwe
#
#        Element Code          Element  Item Code (CPC)      Item  Year Code  \
# 26             5609  Import quantity           2151.0  Chickens       2010
# 27             5622     Import value           2151.0  Chickens       2010
# 28             5909  Export quantity           2151.0  Chickens       2010
# 29             5922     Export value           2151.0  Chickens       2010
# 30             5609  Import quantity           2151.0  Chickens       2011
# ...             ...              ...              ...       ...        ...
# 42775          5922     Export value           2151.0  Chickens       2016
# 42776          5609  Import quantity           2151.0  Chickens       2017
# 42777          5622     Import value           2151.0  Chickens       2017
# 42778          5909  Export quantity           2151.0  Chickens       2017
# 42779          5922     Export value           2151.0  Chickens       2017
#
#        Year      Unit  Value Flag Flag Description Note  Value Extended
# 26     2010   1000 An   3892    A  Official figure  NaN         3892000
# 27     2010  1000 USD   3350    A  Official figure  NaN         3350000
# 28     2010   1000 An      0    E  Estimated value  NaN               0
# 29     2010  1000 USD      0    E  Estimated value  NaN               0
# 30     2011   1000 An   4720    A  Official figure  NaN         4720000
# ...     ...       ...    ...  ...              ...  ...             ...
# 42775  2016  1000 USD   1924    A  Official figure  NaN         1924000
# 42776  2017   1000 An    403    A  Official figure  NaN          403000
# 42777  2017  1000 USD   2064    A  Official figure  NaN         2064000
# 42778  2017   1000 An    211    A  Official figure  NaN          211000
# 42779  2017  1000 USD    653    A  Official figure  NaN          653000
#
# [4882 rows x 16 columns]

# %%
chickens[ ["Element", "Value", "Unit", "Value Extended"] ]
# Out:
#                Element  Value      Unit  Value Extended
# 26     Import quantity   3892   1000 An         3892000
# 27        Import value   3350  1000 USD         3350000
# 28     Export quantity      0   1000 An               0
# 29        Export value      0  1000 USD               0
# 30     Import quantity   4720   1000 An         4720000
# ...                ...    ...       ...             ...
# 42775     Export value   1924  1000 USD         1924000
# 42776  Import quantity    403   1000 An          403000
# 42777     Import value   2064  1000 USD         2064000
# 42778  Export quantity    211   1000 An          211000
# 42779     Export value    653  1000 USD          653000
#
# [4882 rows x 4 columns]

# %%
chickens.to_csv("chickens.csv")

# %%
#chickens_italy_filter = chickens["Area"] == "Italy"
chick_italy = chickens[chickens["Area"] == "Italy"]

# %%
sns.lineplot(data=chick_italy, x="Year", y="Value Extended", hue= "Element")
# Out:
# <Axes: xlabel='Year', ylabel='Value Extended'>
